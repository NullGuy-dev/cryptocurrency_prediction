# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
from itertools import cycle
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
data = pd.read_csv("/content/drive/MyDrive/coin_Bitcoin.csv")
data.head()
# Out:
#    SNo     Name Symbol                 Date  ...        Open       Close  Volume     Marketcap
# 0    1  Bitcoin    BTC  2013-04-29 23:59:59  ...  134.444000  144.539993     0.0  1.603769e+09
# 1    2  Bitcoin    BTC  2013-04-30 23:59:59  ...  144.000000  139.000000     0.0  1.542813e+09
# 2    3  Bitcoin    BTC  2013-05-01 23:59:59  ...  139.000000  116.989998     0.0  1.298955e+09
# 3    4  Bitcoin    BTC  2013-05-02 23:59:59  ...  116.379997  105.209999     0.0  1.168517e+09
# 4    5  Bitcoin    BTC  2013-05-03 23:59:59  ...  106.250000   97.750000     0.0  1.085995e+09
#
# [5 rows x 10 columns]

# %%
pred_period = 5
data["Predicted"] = data[["Close"]].shift(-pred_period)
data.head()
# Out:
#    SNo     Name Symbol                 Date  ...       Close  Volume     Marketcap   Predicted
# 0    1  Bitcoin    BTC  2013-04-29 23:59:59  ...  144.539993     0.0  1.603769e+09  112.500000
# 1    2  Bitcoin    BTC  2013-04-30 23:59:59  ...  139.000000     0.0  1.542813e+09  115.910004
# 2    3  Bitcoin    BTC  2013-05-01 23:59:59  ...  116.989998     0.0  1.298955e+09  112.300003
# 3    4  Bitcoin    BTC  2013-05-02 23:59:59  ...  105.209999     0.0  1.168517e+09  111.500000
# 4    5  Bitcoin    BTC  2013-05-03 23:59:59  ...   97.750000     0.0  1.085995e+09  113.566002
#
# [5 rows x 11 columns]

# %%
scaler = MinMaxScaler()
colm = ["High", "Low", "Open", "Close", "Volume", "Marketcap", "Predicted"]
scaler.fit(data[colm])
data[colm] = scaler.transform(data[colm])
data.head()
# Out:
#    SNo     Name Symbol                 Date  ...     Close  Volume  Marketcap  Predicted
# 0    1  Bitcoin    BTC  2013-04-29 23:59:59  ...  0.001200     0.0   0.000696   0.000695
# 1    2  Bitcoin    BTC  2013-04-30 23:59:59  ...  0.001112     0.0   0.000645   0.000748
# 2    3  Bitcoin    BTC  2013-05-01 23:59:59  ...  0.000765     0.0   0.000439   0.000692
# 3    4  Bitcoin    BTC  2013-05-02 23:59:59  ...  0.000580     0.0   0.000329   0.000679
# 4    5  Bitcoin    BTC  2013-05-03 23:59:59  ...  0.000462     0.0   0.000259   0.000712
#
# [5 rows x 11 columns]

# %%
X = np.array(data[["High", "Low", "Open", "Close", "Volume", "Marketcap"]])
X = X[:-pred_period]

# %%
y = data["Predicted"].values
y = y[:-pred_period]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
rf_reg = RandomForestRegressor(max_depth=7)
rf_reg.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=7)

# %%
from sklearn.metrics import r2_score, mean_squared_error
pred = rf_reg.predict(X_test)
r2 = r2_score(pred, y_test)
mse = mean_squared_error(pred, y_test)
print(f"R2-score: {r2:.3f}")
print(f"MSE: {mse}")
# Out:
# R2-score: 0.983
# MSE: 0.0004985877313031171
